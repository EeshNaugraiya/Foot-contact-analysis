# %%
import os
import glob
import random
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Sequential
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, precision_recall_fscore_support, accuracy_score, f1_score, matthews_corrcoef, confusion_matrix
import warnings 
warnings.filterwarnings("ignore")
# %matplotlib inline
import tensorflow as tf
from tensorflow.keras import layers, Model
from keras.callbacks import EarlyStopping

# %%
import os
import numpy as np
import pandas as pd
import cv2

# Function to create directory if it does not exist
def create_directory(path):
    if not os.path.exists(path):
        os.makedirs(path)

# Base path to the synthetic dataset
base_path = '/kaggle/input/movement-dataset-entire/synthetic_dataset'
# Path to save the frames
frames_base_dir = '/kaggle/working/frames'

test_dir ='/kaggle/input/entire-test-movement-dataset/Abhishek_prashant_input_data'
frame_test_dir ='/kaggle/working/test/frames'

# Create the directory to save frames
create_directory(frames_base_dir)
create_directory(frame_test_dir)
# Initialize lists to hold the dataset

# %%
import os
import cv2
import numpy as np
import pandas as pd

# Initialize lists to store paths and labels
train_image_paths = []
train_foot_contacts = []

# Set a limit on the number of frames to process
frame_limit = 6000
total_frames = 0
stop_processing = False

# Loop through each person folder
for person_folder in os.listdir(base_path):
    if stop_processing:  # Check if processing should stop
        break

    person_path = os.path.join(base_path, person_folder)
    if os.path.isdir(person_path):
        # Loop through each activity folder
        for activity_folder in os.listdir(person_path):
            if stop_processing:  # Check if processing should stop
                break

            activity_path = os.path.join(person_path, activity_folder)
            if os.path.isdir(activity_path):
                # Path to the .npy file containing foot contact data
                foot_contacts_path = os.path.join(activity_path, 'foot_contacts.npy')
                
                if os.path.exists(foot_contacts_path):
                    # Load foot contact labels
                    foot_contact_labels = np.load(foot_contacts_path)
                    
                    # Construct the pattern to match video files
                    video_pattern = f'{activity_folder}_view0.mp4'
                    
                    # Loop through each video file in the activity folder
                    for video_file in os.listdir(activity_path):
                        if stop_processing:  # Check if processing should stop
                            break

                        if video_file == video_pattern:
                            video_path = os.path.join(activity_path, video_file)
                            
                            # Directory to save the frames of the current video
                            frames_dir = os.path.join(frames_base_dir, f'{person_folder}_{activity_folder}')
                            os.makedirs(frames_dir, exist_ok=True)  # Create directory if it doesn't exist
                            
                            # Capture the video from the file
                            cap = cv2.VideoCapture(video_path)
                            if not cap.isOpened():
                                print(f"Error: Could not open video {video_path}")
                                continue
                            
                            frame_count = 0
                            while cap.isOpened():
                                ret, frame = cap.read()
                                if not ret:
                                    break
                                
                                # Save frame as image
                                frame_filename = f'frame_{frame_count:04d}.jpg'
                                frame_path = os.path.join(frames_dir, frame_filename)
                                cv2.imwrite(frame_path, frame)
                                
                                # Append frame path and corresponding foot contact label to lists
                                if frame_count < len(foot_contact_labels):
                                    train_image_paths.append(frame_path)
                                    train_foot_contacts.append(foot_contact_labels[frame_count])
                                
                                frame_count += 1
                                total_frames += 1
                                
                                # Check if the frame limit is reached
                                if total_frames >= frame_limit:
                                    stop_processing = True  # Set flag to stop further processing
                                    print("Frame limit reached.")
                                    break
                            
                            # Release the capture
                            cap.release()
                            print(f"Processed {frame_count} frames from {video_file}")

# Create DataFrame
data = {
    'filename': train_image_paths,
    'left_heel': [label[0] for label in train_foot_contacts],
    'left_toe': [label[1] for label in train_foot_contacts],
    'right_heel': [label[2] for label in train_foot_contacts],
    'right_toe': [label[3] for label in train_foot_contacts]
}

left_leg_values = [label[0] & label[1] for label in train_foot_contacts]
right_leg_values = [label[2] & label[3] for label in train_foot_contacts]

data_left_leg = {
    'filename': train_image_paths,
    'left_leg': left_leg_values
}

data_right_leg = {
    'filename': train_image_paths,
    'right_leg': right_leg_values
}

train_left_df = pd.DataFrame(data_left_leg)
train_right_df = pd.DataFrame(data_right_leg)
train_df = pd.DataFrame(data)

print(train_df.head())
print(train_right_df.head())
print(train_left_df.head())
print(len(train_df))
# Out:
# Processed 60 frames from 449_swing_dancing_view0.mp4
# Processed 60 frames from 1847_baseball_walk_in_view0.mp4
# Processed 60 frames from 378_salsa_dancing_view0.mp4
# Processed 60 frames from 321_boxing_view0.mp4
# Processed 60 frames from 1854_baseball_step_up_to_bat_view0.mp4
# Processed 60 frames from 43_walking_view0.mp4
# Processed 60 frames from 189_baseball_pitching_view0.mp4
# Processed 60 frames from 391_salsa_dancing_view0.mp4
# Processed 60 frames from 2166_standing_turn_90_right_view0.mp4
# Processed 60 frames from 376_salsa_dancing_view0.mp4
# Processed 60 frames from 1855_baseball_milling_idle_view0.mp4
# Processed 60 frames from 2165_standing_turn_90_left_view0.mp4
# Processed 60 frames from 448_salsa_dancing_view0.mp4
# Processed 60 frames from 392_salsa_dancing_view0.mp4
# Processed 60 frames from 326_samba_dancing_view0.mp4
# Processed 60 frames from 1851_baseball_hit_view0.mp4
# Processed 60 frames from 1529_quarterback_pass_view0.mp4
# Processed 60 frames from 328_boxing_view0.mp4
# Processed 60 frames from 453_swing_dancing_view0.mp4
# Processed 60 frames from 1857_baseball_bunt_view0.mp4
# Processed 60 frames from 1856_baseball_strike_view0.mp4
# Processed 60 frames from 340_boxing_view0.mp4
# Processed 60 frames from 28_walking_view0.mp4
# Processed 60 frames from 27_walking_view0.mp4
# Processed 60 frames from 42_crouched_walking_view0.mp4
# Processed 60 frames from 1846_baseball_step_out_view0.mp4
# Processed 60 frames from 451_salsa_dancing_view0.mp4
# Processed 60 frames from 2202_standing_turn_left_90_view0.mp4
# Processed 60 frames from 44_walking_view0.mp4
# Processed 60 frames from 1844_baseball_idle_view0.mp4
# Processed 60 frames from 25_walking_view0.mp4
# Processed 60 frames from 373_samba_dancing_view0.mp4
# Processed 60 frames from 116_baseball_catcher_view0.mp4
# Processed 60 frames from 26_walking_view0.mp4
# Processed 60 frames from 396_samba_dancing_view0.mp4
# Processed 60 frames from 39_walking_view0.mp4
# Processed 60 frames from 293_swing_dancing_view0.mp4
# Processed 60 frames from 286_salsa_dancing_view0.mp4
# Processed 60 frames from 1245_idle_view0.mp4
# Processed 60 frames from 1848_baseball_walk_out_view0.mp4
# Processed 60 frames from 1845_baseball_step_in_view0.mp4
# Processed 60 frames from 1850_baseball_hit_view0.mp4
# Processed 60 frames from 327_samba_dancing_view0.mp4
# Processed 60 frames from 1246_idle_view0.mp4
# Processed 60 frames from 444_salsa_dancing_view0.mp4
# Processed 60 frames from 119_baseball_swing_view0.mp4
# Processed 60 frames from 131_salsa_dancing_view0.mp4
# Processed 60 frames from 2203_standing_turn_right_90_view0.mp4
# Processed 60 frames from 118_baseball_idle_view0.mp4
# Processed 60 frames from 393_samba_dancing_view0.mp4
# Processed 60 frames from 277_samba_dancing_view0.mp4
# Processed 60 frames from 1250_idle_view0.mp4
# Processed 60 frames from 1473_baseball_pitching_view0.mp4
# Processed 60 frames from 301_samba_dancing_view0.mp4
# Processed 60 frames from 445_swing_dancing_view0.mp4
# Processed 60 frames from 1849_baseball_hit_view0.mp4
# Processed 60 frames from 117_baseball_bunt_view0.mp4
# Processed 60 frames from 1192_idle_view0.mp4
# Processed 60 frames from 115_baseball_catcher_view0.mp4
# Processed 60 frames from 443_salsa_dancing_view0.mp4
# Processed 60 frames from 303_swing_dancing_view0.mp4
# Processed 60 frames from 285_samba_dancing_view0.mp4
# Processed 60 frames from 121_baseball_umpire_view0.mp4
# Processed 60 frames from 120_baseball_swing_inside_view0.mp4
# Processed 60 frames from 24_walking_view0.mp4
# Processed 60 frames from 449_swing_dancing_view0.mp4
# Processed 60 frames from 1847_baseball_walk_in_view0.mp4
# Processed 60 frames from 378_salsa_dancing_view0.mp4
# Processed 60 frames from 321_boxing_view0.mp4
# Processed 60 frames from 1854_baseball_step_up_to_bat_view0.mp4
# Processed 60 frames from 43_walking_view0.mp4
# Processed 60 frames from 189_baseball_pitching_view0.mp4
# Processed 60 frames from 391_salsa_dancing_view0.mp4
# Processed 60 frames from 2166_standing_turn_90_right_view0.mp4
# Processed 60 frames from 376_salsa_dancing_view0.mp4
# Processed 60 frames from 1855_baseball_milling_idle_view0.mp4
# Processed 60 frames from 2165_standing_turn_90_left_view0.mp4
# Processed 60 frames from 448_salsa_dancing_view0.mp4
# Processed 60 frames from 392_salsa_dancing_view0.mp4
# Processed 60 frames from 326_samba_dancing_view0.mp4
# Processed 60 frames from 1851_baseball_hit_view0.mp4
# Processed 60 frames from 1529_quarterback_pass_view0.mp4
# Processed 60 frames from 328_boxing_view0.mp4
# Processed 60 frames from 453_swing_dancing_view0.mp4
# Processed 60 frames from 1857_baseball_bunt_view0.mp4
# Processed 60 frames from 1856_baseball_strike_view0.mp4
# Processed 60 frames from 340_boxing_view0.mp4
# Processed 60 frames from 28_walking_view0.mp4
# Processed 60 frames from 27_walking_view0.mp4
# Processed 60 frames from 42_crouched_walking_view0.mp4
# Processed 60 frames from 1846_baseball_step_out_view0.mp4
# Processed 60 frames from 451_salsa_dancing_view0.mp4
# Processed 60 frames from 2202_standing_turn_left_90_view0.mp4
# Processed 60 frames from 44_walking_view0.mp4
# Processed 60 frames from 1844_baseball_idle_view0.mp4
# Processed 60 frames from 25_walking_view0.mp4
# Processed 60 frames from 373_samba_dancing_view0.mp4
# Processed 60 frames from 116_baseball_catcher_view0.mp4
# Processed 60 frames from 26_walking_view0.mp4
# Frame limit reached.
# Processed 60 frames from 396_samba_dancing_view0.mp4
#                                             filename  left_heel  left_toe  \
# 0  /kaggle/working/frames/44944_Stefani_449_swing...          0         0
# 1  /kaggle/working/frames/44944_Stefani_449_swing...          0         0
# 2  /kaggle/working/frames/44944_Stefani_449_swing...          0         0
# 3  /kaggle/working/frames/44944_Stefani_449_swing...          0         0
# 4  /kaggle/working/frames/44944_Stefani_449_swing...          0         0
#
#    right_heel  right_toe
# 0           1          1
# 1           1          1
# 2           1          1
# 3           1          1
# 4           1          1
#                                             filename  right_leg
# 0  /kaggle/working/frames/44944_Stefani_449_swing...          1
# 1  /kaggle/working/frames/44944_Stefani_449_swing...          1
# 2  /kaggle/working/frames/44944_Stefani_449_swing...          1
# 3  /kaggle/working/frames/44944_Stefani_449_swing...          1
# 4  /kaggle/working/frames/44944_Stefani_449_swing...          1
#                                             filename  left_leg
# 0  /kaggle/working/frames/44944_Stefani_449_swing...         0
# 1  /kaggle/working/frames/44944_Stefani_449_swing...         0
# 2  /kaggle/working/frames/44944_Stefani_449_swing...         0
# 3  /kaggle/working/frames/44944_Stefani_449_swing...         0
# 4  /kaggle/working/frames/44944_Stefani_449_swing...         0
# 6000

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
import os

images = []
labels = []

# Define image size and color channels (adjust according to your needs)
img_width, img_height = 256, 256
channels = 3
num_classes = 2
input_shape = (256, 256, 3)

# Preprocess images and labels
for index, row in train_right_df.iterrows():
    img_path = row['filename']
    label = row['right_leg']  # 0 or 1

    # Load and preprocess the image
    img = load_img(img_path, target_size=(img_width, img_height))
    img_array = img_to_array(img)
    images.append(img_array)
    labels.append(label)

# Convert lists to numpy arrays
images = np.array(images)
labels = np.array(labels)

# Split into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)
#x_train = images
#y_train = labels

# Print the shapes
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
#print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (4800, 256, 256, 3) - y_train shape: (4800,)

# %%
import os
import cv2
import pandas as pd
test_image_paths = []
test_foot_contacts = []
# Function to create a directory if it doesn't exist
def create_directory(path):
    if not os.path.exists(path):
        os.makedirs(path)

# Directories
test_dir = '/kaggle/input/entire-test-movement-dataset'
frame_test_dir = '/kaggle/working/test/frames'
create_directory(frame_test_dir)

# Paths to MP4 files and corresponding ground truth CSV files
video_paths = [
    #'/kaggle/input/entire-test-movement-dataset/Abhishek_prashant_input_data/Abhishek/jumping_abhishek.mp4',
    '/kaggle/input/entire-test-movement-dataset/Abhishek_prashant_input_data/Prashant/jumping_video_prashant_gupta.mp4'
]

ground_truth_paths = [
    #'/kaggle/input/entire-test-movement-dataset/Abhishek_prashant_input_data/Abhishek/ground_truth/abhishek jumping video.csv',
    '/kaggle/input/entire-test-movement-dataset/Abhishek_prashant_input_data/Prashant/ground_truth/prashant jumping video.csv'
]

# Initialize lists for DataFrame
test_image_paths = []
test_foot_contacts = []

# Set a limit on the number of frames to process
MAX_FRAMES = 200
total_frames_processed = 0

# Process each video and its corresponding ground truth
for video_path, gt_path in zip(video_paths, ground_truth_paths):
    if total_frames_processed >= MAX_FRAMES:
        break

    # Read the ground truth CSV
    ground_truth_df = pd.read_csv(gt_path)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        continue
    
    # Extract video identifier (base name of video file without extension)
    video_id = os.path.splitext(os.path.basename(video_path))[0]
    
    frame_count = 0
    while cap.isOpened():
        if total_frames_processed >= MAX_FRAMES:
            break

        ret, frame = cap.read()
        if not ret:
            break
        
        # Save frame as image with video identifier
        frame_filename = f'{video_id}_frame_{total_frames_processed:04d}.jpg'
        frame_path = os.path.join(frame_test_dir, frame_filename)
        cv2.imwrite(frame_path, frame)
        
        # Get foot contact data for the current frame
        if frame_count < len(ground_truth_df):
            left_foot = ground_truth_df.iloc[frame_count]['left_foot']
            right_foot = ground_truth_df.iloc[frame_count]['right_foot']
            test_image_paths.append(frame_path)
            test_foot_contacts.append([left_foot, right_foot])
        
        frame_count += 1
        total_frames_processed += 1

    cap.release()
    print(f"Processed {frame_count} frames from {video_path}")

    if total_frames_processed >= MAX_FRAMES:
        break

# Create DataFrames
test_df = pd.DataFrame({
    'filename': test_image_paths,
    'left_leg': [label[0] for label in test_foot_contacts],
    'right_leg': [label[1] for label in test_foot_contacts]
})

# Create DataFrames for left and right foot separately if needed
test_left_df = pd.DataFrame({
    'filename': test_image_paths,
    'left_leg': [label[0] for label in test_foot_contacts]
})

test_right_df = pd.DataFrame({
    'filename': test_image_paths,
    'right_leg': [label[1] for label in test_foot_contacts]
})

# Print the first few rows of each DataFrame
print(test_df.head())
print(test_left_df.head())
print(test_right_df.head())
# Out:
# Processed 200 frames from /kaggle/input/entire-test-movement-dataset/Abhishek_prashant_input_data/Prashant/jumping_video_prashant_gupta.mp4
#                                             filename  left_leg  right_leg
# 0  /kaggle/working/test/frames/jumping_video_pras...         1          1
# 1  /kaggle/working/test/frames/jumping_video_pras...         1          1
# 2  /kaggle/working/test/frames/jumping_video_pras...         1          1
# 3  /kaggle/working/test/frames/jumping_video_pras...         1          1
# 4  /kaggle/working/test/frames/jumping_video_pras...         1          1
#                                             filename  left_leg
# 0  /kaggle/working/test/frames/jumping_video_pras...         1
# 1  /kaggle/working/test/frames/jumping_video_pras...         1
# 2  /kaggle/working/test/frames/jumping_video_pras...         1
# 3  /kaggle/working/test/frames/jumping_video_pras...         1
# 4  /kaggle/working/test/frames/jumping_video_pras...         1
#                                             filename  right_leg
# 0  /kaggle/working/test/frames/jumping_video_pras...          1
# 1  /kaggle/working/test/frames/jumping_video_pras...          1
# 2  /kaggle/working/test/frames/jumping_video_pras...          1
# 3  /kaggle/working/test/frames/jumping_video_pras...          1
# 4  /kaggle/working/test/frames/jumping_video_pras...          1

# %%
# Load and preprocess test images and labels
test_images = []
test_labels = []

for index, row in test_left_df.iterrows():
    img_path = row['filename']  # Adjust the column name if it's different
    label = row['left_leg']    # 0 or 1

    # Load and preprocess the image
    img = load_img(img_path, target_size=(img_width, img_height))
    img_array = img_to_array(img)
    test_images.append(img_array)
    test_labels.append(label)

# Convert lists to numpy arrays
x_test1 = np.array(test_images)
y_test1 = np.array(test_labels)

# Print the shape of the test dataset
print(f"test_images shape: {x_test.shape} - test_labels shape: {y_test.shape}")
# Out:
# test_images shape: (1200, 256, 256, 3) - test_labels shape: (1200,)

# %%
import keras
from keras import layers
from keras import ops

import numpy as np
import matplotlib.pyplot as plt

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 16
num_epochs = 400  # For real training, use num_epochs=100. 10 is a test value
image_size = 256  # We'll resize input images to this size
patch_size = 16  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [
    2048,
    1024,
]

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=keras.activations.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    def call(self, images):
        input_shape = ops.shape(images)
        batch_size = input_shape[0]
        height = input_shape[1]
        width = input_shape[2]
        channels = input_shape[3]
        num_patches_h = height // self.patch_size
        num_patches_w = width // self.patch_size
        patches = keras.ops.image.extract_patches(images, size=self.patch_size)
        patches = ops.reshape(
            patches,
            (
                batch_size,
                num_patches_h * num_patches_w,
                self.patch_size * self.patch_size * channels,
            ),
        )
        return patches

    def get_config(self):
        config = super().get_config()
        config.update({"patch_size": self.patch_size})
        return config

# %%
plt.figure(figsize=(4, 4))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("uint8"))
plt.axis("off")

resized_image = ops.image.resize(
    ops.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = ops.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(ops.convert_to_numpy(patch_img).astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 256 X 256
# Patch size: 16 X 16
# Patches per image: 256
# Elements per patch: 768

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = ops.expand_dims(
            ops.arange(start=0, stop=self.num_patches, step=1), axis=0
        )
        projected_patches = self.projection(patch)
        encoded = projected_patches + self.position_embedding(positions)
        return encoded

    def get_config(self):
        config = super().get_config()
        config.update({"num_patches": self.num_patches})
        return config

# %%
def create_vit_classifier():
    inputs = keras.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
def run_experiment(model):
    optimizer = keras.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "/kaggle/working/abhishek/left/checkpoint.weights.h5"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )
    
    early_stopping_callback = EarlyStopping(
        monitor="val_loss",
        patience=20,
        restore_best_weights=True
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[checkpoint_call
400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.6827 - loss: 0.5967 - top-5-accuracy: 1.0000 - val_accuracy: 0.6833 - val_loss: 0.5602 - val_top-5-accuracy: 1.0000
# Epoch 19/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.6607 - loss: 0.6094 - top-5-accuracy: 1.0000 - val_accuracy: 0.6958 - val_loss: 0.5592 - val_top-5-accuracy: 1.0000
# Epoch 20/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.6779 - loss: 0.5956 - top-5-accuracy: 1.0000 - val_accuracy: 0.7042 - val_loss: 0.5458 - val_top-5-accuracy: 1.0000
# Epoch 21/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 72ms/step - accuracy: 0.6813 - loss: 0.5938 - top-5-accuracy: 1.0000 - val_accuracy: 0.7125 - val_loss: 0.5414 - val_top-5-accuracy: 1.0000
# Epoch 22/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 21s 77ms/step - accuracy: 0.6880 - loss: 0.5894 - top-5-accuracy: 1.0000 - val_accuracy: 0.7271 - val_loss: 0.5466 - val_top-5-accuracy: 1.0000
# Epoch 23/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.6715 - loss: 0.5993 - top-5-accuracy: 1.0000 - val_accuracy: 0.7104 - val_loss: 0.5429 - val_top-5-accuracy: 1.0000
# Epoch 24/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 72ms/step - accuracy: 0.6889 - loss: 0.5841 - top-5-accuracy: 1.0000 - val_accuracy: 0.7042 - val_loss: 0.5383 - val_top-5-accuracy: 1.0000
# Epoch 25/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 21s 78ms/step - accuracy: 0.6806 - loss: 0.5845 - top-5-accuracy: 1.0000 - val_accuracy: 0.7375 - val_loss: 0.5264 - val_top-5-accuracy: 1.0000
# Epoch 26/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.6987 - loss: 0.5687 - top-5-accuracy: 1.0000 - val_accuracy: 0.7125 - val_loss: 0.5447 - val_top-5-accuracy: 1.0000
# Epoch 27/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.6827 - loss: 0.5787 - top-5-accuracy: 1.0000 - val_accuracy: 0.7083 - val_loss: 0.5379 - val_top-5-accuracy: 1.0000
# Epoch 28/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.6899 - loss: 0.5787 - top-5-accuracy: 1.0000 - val_accuracy: 0.7167 - val_loss: 0.5485 - val_top-5-accuracy: 1.0000
# Epoch 29/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.6969 - loss: 0.5721 - top-5-accuracy: 1.0000 - val_accuracy: 0.7188 - val_loss: 0.5409 - val_top-5-accuracy: 1.0000
# Epoch 30/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.7033 - loss: 0.5669 - top-5-accuracy: 1.0000 - val_accuracy: 0.7188 - val_loss: 0.5193 - val_top-5-accuracy: 1.0000
# Epoch 31/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.6963 - loss: 0.5653 - top-5-accuracy: 1.0000 - val_accuracy: 0.7188 - val_loss: 0.5136 - val_top-5-accuracy: 1.0000
# Epoch 32/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.7035 - loss: 0.5527 - top-5-accuracy: 1.0000 - val_accuracy: 0.7188 - val_loss: 0.5133 - val_top-5-accuracy: 1.0000
# Epoch 33/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 72ms/step - accuracy: 0.6940 - loss: 0.5647 - top-5-accuracy: 1.0000 - val_accuracy: 0.7021 - val_loss: 0.5148 - val_top-5-accuracy: 1.0000
# Epoch 34/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.7094 - loss: 0.5484 - top-5-accuracy: 1.0000 - val_accuracy: 0.7208 - val_loss: 0.5139 - val_top-5-accuracy: 1.0000
# Epoch 35/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.6885 - loss: 0.5624 - top-5-accuracy: 1.0000 - val_accuracy: 0.7146 - val_loss: 0.5188 - val_top-5-accuracy: 1.0000
# Epoch 36/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 72ms/step - accuracy: 0.7361 - loss: 0.5285 - top-5-accuracy: 1.0000 - val_accuracy: 0.6896 - val_loss: 0.5295 - val_top-5-accuracy: 1.0000
# Epoch 37/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 72ms/step - accuracy: 0.7048 - loss: 0.5589 - top-5-accuracy: 1.0000 - val_accuracy: 0.7250 - val_loss: 0.5017 - val_top-5-accuracy: 1.0000
# Epoch 38/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 72ms/step - accuracy: 0.
 1.0000 - val_accuracy: 0.8750 - val_loss: 0.2902 - val_top-5-accuracy: 1.0000
# Epoch 115/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.8140 - loss: 0.3679 - top-5-accuracy: 1.0000 - val_accuracy: 0.8500 - val_loss: 0.3182 - val_top-5-accuracy: 1.0000
# Epoch 116/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8271 - loss: 0.3616 - top-5-accuracy: 1.0000 - val_accuracy: 0.8729 - val_loss: 0.2977 - val_top-5-accuracy: 1.0000
# Epoch 117/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.8420 - loss: 0.3454 - top-5-accuracy: 1.0000 - val_accuracy: 0.8625 - val_loss: 0.2977 - val_top-5-accuracy: 1.0000
# Epoch 118/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8355 - loss: 0.3703 - top-5-accuracy: 1.0000 - val_accuracy: 0.8604 - val_loss: 0.2965 - val_top-5-accuracy: 1.0000
# Epoch 119/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8219 - loss: 0.3769 - top-5-accuracy: 1.0000 - val_accuracy: 0.8604 - val_loss: 0.2850 - val_top-5-accuracy: 1.0000
# Epoch 120/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8390 - loss: 0.3419 - top-5-accuracy: 1.0000 - val_accuracy: 0.8625 - val_loss: 0.2831 - val_top-5-accuracy: 1.0000
# Epoch 121/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8339 - loss: 0.3785 - top-5-accuracy: 1.0000 - val_accuracy: 0.8604 - val_loss: 0.2865 - val_top-5-accuracy: 1.0000
# Epoch 122/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.8360 - loss: 0.3549 - top-5-accuracy: 1.0000 - val_accuracy: 0.8625 - val_loss: 0.2880 - val_top-5-accuracy: 1.0000
# Epoch 123/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8199 - loss: 0.3684 - top-5-accuracy: 1.0000 - val_accuracy: 0.8562 - val_loss: 0.2929 - val_top-5-accuracy: 1.0000
# Epoch 124/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 21s 78ms/step - accuracy: 0.8219 - loss: 0.3626 - top-5-accuracy: 1.0000 - val_accuracy: 0.8833 - val_loss: 0.2806 - val_top-5-accuracy: 1.0000
# Epoch 125/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 72ms/step - accuracy: 0.8343 - loss: 0.3612 - top-5-accuracy: 1.0000 - val_accuracy: 0.8667 - val_loss: 0.2915 - val_top-5-accuracy: 1.0000
# Epoch 126/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8317 - loss: 0.3691 - top-5-accuracy: 1.0000 - val_accuracy: 0.8625 - val_loss: 0.2888 - val_top-5-accuracy: 1.0000
# Epoch 127/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8419 - loss: 0.3504 - top-5-accuracy: 1.0000 - val_accuracy: 0.8771 - val_loss: 0.2796 - val_top-5-accuracy: 1.0000
# Epoch 128/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8425 - loss: 0.3549 - top-5-accuracy: 1.0000 - val_accuracy: 0.8792 - val_loss: 0.2877 - val_top-5-accuracy: 1.0000
# Epoch 129/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8451 - loss: 0.3334 - top-5-accuracy: 1.0000 - val_accuracy: 0.8771 - val_loss: 0.2771 - val_top-5-accuracy: 1.0000
# Epoch 130/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 72ms/step - accuracy: 0.8507 - loss: 0.3253 - top-5-accuracy: 1.0000 - val_accuracy: 0.8729 - val_loss: 0.2810 - val_top-5-accuracy: 1.0000
# Epoch 131/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8376 - loss: 0.3605 - top-5-accuracy: 1.0000 - val_accuracy: 0.8583 - val_loss: 0.2672 - val_top-5-accuracy: 1.0000
# Epoch 132/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 21s 77ms/step - accuracy: 0.8464 - loss: 0.3363 - top-5-accuracy: 1.0000 - val_accuracy: 0.8938 - val_loss: 0.2698 - val_top-5-accuracy: 1.0000
# Epoch 133/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 72ms/step - accuracy: 0.8398 - loss: 0.3503 - top-5-accuracy: 1.0000 - val_accuracy: 0.8833 - val_loss: 0.2820 - val_top-5-accuracy: 1.0000
# Epoch 134/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.8407 - loss: 0.3370 - top-5-accuracy: 1.0000 - val_accuracy: 0.8750 - val_loss: 0.2721 - val_top-5-accuracy: 1.0000
# Epoch 135/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8445 - loss: 0.3350 - top-5-accuracy: 1.0000 - val_accuracy: 0.8667 - val_loss: 0.2780 - val_top-5-accuracy: 1.0000
# Epoch 136/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8507 - loss: 0.3262 - top-5-accuracy: 1.0000 - val_accuracy: 0.8792 - val_loss: 0.2740 - val_top-5-accuracy: 1.0000
# Epoch 137/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.8358 - loss: 0.3486 - top-5-accuracy: 1.0000 - val_accuracy: 0.8667 - val_loss: 0.2817 - val_top-5-accuracy: 1.0000
# Epoch 138/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8390 - loss: 0.3351 - top-5-accuracy: 1.0000 - val_accuracy: 0.8792 - val_loss: 0.2718 - val_top-5-accuracy: 1.0000
# Epoch 139/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 72ms/step - accuracy: 0.8503 - loss: 0.3332 - top-5-accuracy: 1.0000 - val_accuracy: 0.8625 - val_loss: 0.2899 - val_top-5-accuracy: 1.0000
# Epoch 140/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 74ms/step - accuracy: 0.8328 - loss: 0.3434 - top-5-accuracy: 1.0000 - val_accuracy: 0.8854 - val_loss: 0.2670 - val_top-5-accuracy: 1.0000
# Epoch 141/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.8344 - loss: 0.3524 - top-5-accuracy: 1.0000 - val_accuracy: 0.8667 - val_loss: 0.2956 - val_top-5-accuracy: 1.0000
# Epoch 142/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.8385 - loss: 0.3578 - top-5-accuracy: 1.0000 - val_accuracy: 0.8729 - val_loss: 0.2773 - val_top-5-accuracy: 1.0000
# Epoch 143/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8430 - loss: 0.3316 - top-5-accuracy: 1.0000 - val_accuracy: 0.8646 - val_loss: 0.2864 - val_top-5-accuracy: 1.0000
# Epoch 144/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8406 - loss: 0.3220 - top-5-accuracy: 1.0000 - val_accuracy: 0.8917 - val_loss: 0.2623 - val_top-5-accuracy: 1.0000
# Epoch 145/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8372 - loss: 0.3376 - top-5-accuracy: 1.0000 - val_accuracy: 0.8771 - val_loss: 0.2804 - val_top-5-accuracy: 1.0000
# Epoch 146/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 71ms/step - accuracy: 0.8491 - loss: 0.3242 - top-5-accuracy: 1.0000 - val_accuracy: 0.8875 - val_loss: 0.2639 - val_top-5-accuracy: 1.0000
# Epoch 147/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8544 - loss: 0.3135 - top-5-accuracy: 1.0000 - val_accuracy: 0.8771 - val_loss: 0.2828 - val_top-5-accuracy: 1.0000
# Epoch 148/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8534 - loss: 0.3180 - top-5-accuracy: 1.0000 - val_accuracy: 0.8854 - val_loss: 0.2742 - val_top-5-accuracy: 1.0000
# Epoch 149/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 72ms/step - accuracy: 0.8457 - loss: 0.3275 - top-5-accuracy: 1.0000 - val_accuracy: 0.8833 - val_loss: 0.2734 - val_top-5-accuracy: 1.0000
# Epoch 150/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 74ms/step - accuracy: 0.8507 - loss: 0.3257 - top-5-accuracy: 1.0000 - val_accuracy: 0.8896 - val_loss: 0.2492 - val_top-5-accuracy: 1.0000
# Epoch 151/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8464 - loss: 0.3400 - top-5-accuracy: 1.0000 - val_accuracy: 0.8813 - val_loss: 0.2627 - val_top-5-accuracy: 1.0000
# Epoch 152/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 74ms/step - accuracy: 0.8431 - loss: 0.3300 - top-5-accuracy: 1.0000 - val_accuracy: 0.8917 - val_loss: 0.2673 - val_top-5-accuracy: 1.0000
# Epoch 153/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 72ms/step - accuracy: 0.8568 - loss: 0.3403 - top-5-accuracy: 1.0000 - val_accuracy: 0.8750 - val_loss: 0.2622 - val_top-5-accuracy: 1.0000
# Epoch 154/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 72ms/step - accuracy: 0.8402 - loss: 0.3348 - top-5-accuracy: 1.0000 - val_accuracy: 0.8896 - val_loss: 0.2571 - val_top-5-accuracy: 1.0000
# Epoch 155/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8542 - loss: 0.3241 - top-5-accuracy: 1.0000 - val_accuracy: 0.8708 - val_loss: 0.2656 - val_top-5-accuracy: 1.0000
# Epoch 156/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.8632 - loss: 0.3114 - top-5-accuracy: 1.0000 - val_accuracy: 0.8813 - val_loss: 0.2695 - val_top-5-accuracy: 1.0000
# Epoch 157/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8614 - loss: 0.3124 - top-5-accuracy: 1.0000 - val_accuracy: 0.8813 - val_loss: 0.2527 - val_top-5-accuracy: 1.0000
# Epoch 158/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 21s 77ms/step - accuracy: 0.8320 - loss: 0.3455 - top-5-accuracy: 1.0000 - val_accuracy: 0.8979 - val_loss: 0.2494 - val_top-5-accuracy: 1.0000
# Epoch 159/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8598 - loss: 0.3154 - top-5-accuracy: 1.0000 - val_accuracy: 0.8896 - val_loss: 0.2534 - val_top-5-accuracy: 1.0000
# Epoch 160/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 74ms/step - accuracy: 0.8483 - loss: 0.3409 - top-5-accuracy: 1.0000 - val_accuracy: 0.8854 - val_loss: 0.2550 - val_top-5-accuracy: 1.0000
# Epoch 161/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8588 - loss: 0.3075 - top-5-accuracy: 1.0000 - val_accuracy: 0.8938 - val_loss: 0.2401 - val_top-5-accuracy: 1.0000
# Epoch 162/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 74ms/step - accuracy: 0.8602 - loss: 0.3111 - top-5-accuracy: 1.0000 - val_accuracy: 0.8875 - val_loss: 0.2696 - val_top-5-accuracy: 1.0000
# Epoch 163/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8535 - loss: 0.3396 - top-5-accuracy: 1.0000 - val_accuracy: 0.8833 - val_loss: 0.2532 - val_top-5-accuracy: 1.0000
# Epoch 164/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8462 - loss: 0.3298 - top-5-accuracy: 1.0000 - val_accuracy: 0.8750 - val_loss: 0.2496 - val_top-5-accuracy: 1.0000
# Epoch 165/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8551 - loss: 0.3042 - top-5-accuracy: 1.0000 - val_accuracy: 0.8958 - val_loss: 0.2426 - val_top-5-accuracy: 1.0000
# Epoch 166/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 76ms/step - accuracy: 0.8633 - loss: 0.3172 - top-5-accuracy: 1.0000 - val_accuracy: 0.8813 - val_loss: 0.2578 - val_top-5-accuracy: 1.0000
# Epoch 167/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 74ms/step - accuracy: 0.8660 - loss: 0.2992 - top-5-accuracy: 1.0000 - val_accuracy: 0.8917 - val_loss: 0.2496 - val_top-5-accuracy: 1.0000
# Epoch 168/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 74ms/step - accuracy: 0.8688 - loss: 0.2986 - top-5-accuracy: 1.0000 - val_accuracy: 0.8687 - val_loss: 0.2693 - val_top-5-accuracy: 1.0000
# Epoch 169/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 74ms/step - accuracy: 0.8438 - loss: 0.3304 - top-5-accuracy: 1.0000 - val_accuracy: 0.8625 - val_loss: 0.2805 - val_top-5-accuracy: 1.0000
# Epoch 170/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 74ms/step - accuracy: 0.8526 - loss: 0.3323 - top-5-accuracy: 1.0000 - val_accuracy: 0.8833 - val_loss: 0.2687 - val_top-5-accuracy: 1.0000
# Epoch 171/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 74ms/step - accuracy: 0.8614 - loss: 0.3201 - top-5-accuracy: 1.0000 - val_accuracy: 0.8875 - val_loss: 0.2575 - val_top-5-accuracy: 1.0000
# Epoch 172/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 74ms/step - accuracy: 0.8730 - loss: 0.2983 - top-5-accuracy: 1.0000 - val_accuracy: 0.8896 - val_loss: 0.2371 - val_top-5-accuracy: 1.0000
# Epoch 173/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8593 - loss: 0.3181 - top-5-accuracy: 1.0000 - val_accuracy: 0.8979 - val_loss: 0.2524 - val_top-5-accuracy: 1.0000
# Epoch 174/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8584 - loss: 0.3197 - top-5-accuracy: 1.0000 - val_accuracy: 0.8729 - val_loss: 0.2642 - val_top-5-accuracy: 1.0000
# Epoch 175/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 72ms/step - accuracy: 0.8541 - loss: 0.3234 - top-5-accuracy: 1.0000 - val_accuracy: 0.8917 - val_loss: 0.2583 - val_top-5-accuracy: 1.0000
# Epoch 176/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8758 - loss: 0.2921 - top-5-accuracy: 1.0000 - val_accuracy: 0.8979 - val_loss: 0.2478 - val_top-5-accuracy: 1.0000
# Epoch 177/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 21s 79ms/step - accuracy: 0.8527 - loss: 0.3147 - top-5-accuracy: 1.0000 - val_accuracy: 0.9000 - val_loss: 0.2459 - val_top-5-accuracy: 1.0000
# Epoch 178/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8682 - loss: 0.3022 - top-5-accuracy: 1.0000 - val_accuracy: 0.8875 - val_loss: 0.2643 - val_top-5-accuracy: 1.0000
# Epoch 179/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 22s 81ms/step - accuracy: 0.8630 - loss: 0.2946 - top-5-accuracy: 1.0000 - val_accuracy: 0.9042 - val_loss: 0.2599 - val_top-5-accuracy: 1.0000
# Epoch 180/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8640 - loss: 0.3162 - top-5-accuracy: 1.0000 - val_accuracy: 0.8792 - val_loss: 0.2668 - val_top-5-accuracy: 1.0000
# Epoch 181/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 74ms/step - accuracy: 0.8654 - loss: 0.3034 - top-5-accuracy: 1.0000 - val_accuracy: 0.8958 - val_loss: 0.2532 - val_top-5-accuracy: 1.0000
# Epoch 182/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8618 - loss: 0.3096 - top-5-accuracy: 1.0000 - val_accuracy: 0.8958 - val_loss: 0.2478 - val_top-5-accuracy: 1.0000
# Epoch 183/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 21s 79ms/step - accuracy: 0.8708 - loss: 0.3027 - top-5-accuracy: 1.0000 - val_accuracy: 0.9083 - val_loss: 0.2528 - val_top-5-accuracy: 1.0000
# Epoch 184/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8525 - loss: 0.3194 - top-5-accuracy: 1.0000 - val_accuracy: 0.8917 - val_loss: 0.2658 - val_top-5-accuracy: 1.0000
# Epoch 185/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8618 - loss: 0.3085 - top-5-accuracy: 1.0000 - val_accuracy: 0.9021 - val_loss: 0.2711 - val_top-5-accuracy: 1.0000
# Epoch 186/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8565 - loss: 0.3092 - top-5-accuracy: 1.0000 - val_accuracy: 0.9062 - val_loss: 0.2435 - val_top-5-accuracy: 1.0000
# Epoch 187/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.8636 - loss: 0.3025 - top-5-accuracy: 1.0000 - val_accuracy: 0.9000 - val_loss: 0.2639 - val_top-5-accuracy: 1.0000
# Epoch 188/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8618 - loss: 0.3066 - top-5-accuracy: 1.0000 - val_accuracy: 0.8854 - val_loss: 0.2647 - val_top-5-accuracy: 1.0000
# Epoch 189/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8601 - loss: 0.3051 - top-5-accuracy: 1.0000 - val_accuracy: 0.9062 - val_loss: 0.2466 - val_top-5-accuracy: 1.0000
# Epoch 190/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8713 - loss: 0.2890 - top-5-accuracy: 1.0000 - val_accuracy: 0.9062 - val_loss: 0.2444 - val_top-5-accuracy: 1.0000
# Epoch 191/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.8723 - loss: 0.2758 - top-5-accuracy: 1.0000 - val_accuracy: 0.8979 - val_loss: 0.2759 - val_top-5-accuracy: 1.0000
# Epoch 192/400
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.8488 - loss: 0.3183 - top-5-accuracy: 1.0000 - val_accuracy: 0.8958 - val_loss: 0.2421 - val_top-5-accuracy: 1.0000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.7505 - loss: 5.8342 - top-5-accuracy: 1.0000
# Test accuracy: 70.0%
# Test top 5 accuracy: 100.0%
